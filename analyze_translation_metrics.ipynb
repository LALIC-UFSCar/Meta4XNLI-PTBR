# %% [markdown]
# # Translations metrics analysis

# %% [markdown]
# ## Setup

# %%
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## Prepare data

# %%
# Reads all TSV files in the current directory
def summarize_metric(directory_path: str, metric_name: str) -> pd.DataFrame:
    """
    Summarizes a specific metric from all TSV files in a directory using pandas.Series.describe().

    Args:
        directory_path (str): Path to the directory containing TSV files.
        metric_name (str): The name of the column (metric) to summarize.

    Returns:
        pd.DataFrame: A DataFrame where each row corresponds to a TSV file and each column is an index from describe().
    """
    directory = Path(directory_path)
    if not directory.is_dir():
        raise ValueError(f"The provided path '{directory_path}' is not a valid directory.")

    summary_data = []

    for tsv_file in directory.glob("*.tsv"):
        try:
            df = pd.read_csv(tsv_file, sep='\t')
            if metric_name not in df.columns:
                print(f"Metric '{metric_name}' not found in file '{tsv_file.name}'. Skipping.")
                continue

            # Apply describe() to the specified metric column
            metric_summary = df[metric_name].describe()

            # Append the summary as a row with the file name as the index
            summary_data.append(pd.DataFrame(metric_summary).T.assign(file_name=tsv_file.name))
        except Exception as e:
            print(f"Error processing file '{tsv_file.name}': {e}")

    # Combine all summaries into a single DataFrame
    if summary_data:
        result_df = pd.concat(summary_data, ignore_index=True)
        result_df.set_index('file_name', inplace=True)
        result_df.reset_index(inplace=True)
        return result_df
    else:
        print("No valid TSV files processed.")
        return pd.DataFrame()

# %%
df = summarize_metric('results/en2es/full_results', 'comet_ref')

# %% [markdown]
# ## Analysis

# %%
df
# Out:
#                                             file_name   count      mean  \
# 0   meta-llama_llama-4-scout-17b-16e-instruct_r7m_...  1000.0  0.956281
# 1   gpt-4.1-nano_r3_spt4m_spt4l_upt1_meta4xnli_tra...  1000.0  0.959605
# 2   meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.968827
# 3   mistral-saba-24b_r3_spt4m_spt4l_upt1_meta4xnli...  1000.0  0.966101
# 4   llama-3.1-8b-instant_r3_spt4m_spt4l_upt1_meta4...  1000.0  0.957577
# 5   meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.957881
# 6   llama-3.3-70b-versatile_r3_spt4m_spt4l_upt1_me...  1000.0  0.966617
# 7   gemma2-9b-it_r3_spt4m_spt4l_upt1_meta4xnli_tra...  1000.0  0.913171
# 8   meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.968690
# 9   meta-llama_llama-4-scout-17b-16e-instruct_r5l_...  1000.0  0.969661
# 10  meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.958008
# 11  allam-2-7b_r3_spt4m_spt4l_upt1_meta4xnli_train...  1000.0  0.928278
# 12  llama3-70b-8192_r3_spt4m_spt4l_upt1_meta4xnli_...  1000.0  0.938224
# 13  meta-llama_llama-4-scout-17b-16e-instruct_r6m_...  1000.0  0.956003
# 14  meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.957382
# 15  mistral-saba-24b_r3_spt4m_spt4l_upt1_meta4xnli...  1000.0  0.950382
# 16  meta-llama_llama-4-scout-17b-16e-instruct_r3_s...  1000.0  0.969648
# 17  llama-3.3-70b-versatile_r3_spt4m_spt4l_upt1_me...  1000.0  0.955004
# 18  llama-3.1-8b-instant_r3_spt4m_spt4l_upt1_meta4...  1000.0  0.943231
# 19  llama3-70b-8192_r3_spt4m_spt4l_upt1_meta4xnli_...  1000.0  0.962777
# 20  allam-2-7b_r3_spt4m_spt4l_upt1_meta4xnli_train...  1000.0  0.893098
# 21  llama3-8b-8192_r3_spt4m_spt4l_upt1_meta4xnli_t...  1000.0  0.937481
# 22  meta-llama_llama-4-maverick-17b-128e-instruct_...  1000.0  0.968749
# 23  gpt-4.1-nano_r3_spt4m_spt4l_upt1_meta4xnli_tra...  1000.0  0.970698
# 24  meta-llama_llama-4-scout-17b-16e-instruct_r4l_...  1000.0  0.970230
# 25  llama3-8b-8192_r3_spt4m_spt4l_upt1_meta4xnli_t...  1000.0  0.954174
# 26  gemma2-9b-it_r3_spt4m_spt4l_upt1_meta4xnli_tra...  1000.0  0.940940
# 27  meta-llama_llama-4-scout-17b-16e-instruct_r3_s...  1000.0  0.958324
#
#          std       min       25%       50%       75%  max
# 0   0.080451  0.226214  0.952224  0.988632  1.000000  1.0
# 1   0.070247  0.493320  0.956625  0.989430  1.000000  1.0
# 2   0.059328  0.493226  0.966798  0.991200  1.000000  1.0
# 3   0.059670  0.608032  0.965112  0.990979  1.000000  1.0
# 4   0.080903  0.264020  0.957427  0.989978  1.000000  1.0
# 5   0.072383  0.492707  0.951127  0.990218  1.000000  1.0
# 6   0.062684  0.491158  0.968793  0.991200  1.000000  1.0
# 7   0.189142  0.200866  0.947344  0.990435  1.000000  1.0
# 8   0.059469  0.493226  0.965951  0.991200  1.000000  1.0
# 9   0.059987  0.373493  0.969706  0.991200  1.000000  1.0
# 10  0.072298  0.511672  0.952890  0.989601  1.000000  1.0
# 11  0.103567  0.217396  0.897955  0.975131  0.994604  1.0
# 12  0.095465  0.321945  0.914984  0.980362  0.997872  1.0
# 13  0.080083  0.212875  0.951826  0.989170  1.000000  1.0
# 14  0.071643  0.493566  0.948683  0.989400  1.000000  1.0
# 15  0.083770  0.259789  0.937471  0.985265  0.999994  1.0
# 16  0.061357  0.333111  0.969975  0.991200  1.000000  1.0
# 17  0.081448  0.137208  0.950094  0.987849  1.000000  1.0
# 18  0.087363  0.352210  0.922845  0.981789  0.999271  1.0
# 19  0.067477  0.438986  0.961214  0.990181  1.000000  1.0
# 20  0.131085  0.016914  0.835121  0.949535  0.991200  1.0
# 21  0.092406  0.331362  0.916431  0.979078  0.996479  1.0
# 22  0.059756  0.472662  0.967192  0.991200  1.000000  1.0
# 23  0.057449  0.545068  0.971431  0.991200  1.000000  1.0
# 24  0.059183  0.373493  0.970412  0.991200  1.000000  1.0
# 25  0.080831  0.311734  0.950179  0.987797  1.000000  1.0
# 26  0.124655  0.202042  0.945953  0.986336  0.999718  1.0
# 27  0.074486  0.231261  0.955500  0.988597  1.000000  1.0
